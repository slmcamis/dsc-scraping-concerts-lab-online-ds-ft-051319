# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
#import re

# %%
html_page = requests.get('https://www.residentadvisor.net/events')
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in New York, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, new, york, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=73_zn4f444Ms1nbtnaddvbDUe15CsJN6vhoNK7oQovg1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=w7DJdRHlwvlSlvivLjU2DnToUsYFU7IYixebCORYtxw1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/newyork").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "NewYork"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?636958562503013488"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mNewTracks"><a ga-event-action="New Tracks" ga-event-category="nav" ga-on="click" href="/tracks">
# New Tracks</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=LgsUcPmpTNV0nNOC1wz8x1BB-Dw1HtLyGXWG1QRD1nI1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=ypC8hMlP93BPGDxlPHxkLfBbx-tGmEvbDg3uC-IVXi41"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./events" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="RnGjXWjHtUtaa4bKuMxBnZQnKDybSIiCeFl7vmYLuCgOLU58CXp+mIVoU8C6c4OoeJcb9sjSfzRqF2cmieQR+fD0PrU="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in New York</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Thu, 13 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275181"><img class="nohide" src="/images/events/flyer/2019/6/us-0613-1275181-list.jpg"/></a>
# <p class="counter nohide">
# <span>571</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275181">
# <h1>
# Morgana [free entry]: Atish, John Tejada Live, Nicone, Patricio
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 15 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1254429"><img class="nohide" src="/images/events/flyer/2019/6/us-0615-1254429-list.jpg"/></a>
# <p class="counter nohide">
# <span>342</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1254429">
# <h1>
# La Luna - The Black Madonna, DJ Harvey, DJ Tennis, Moodymann
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=69401">Knockdown Center</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 15 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1248533"><img class="nohide" src="/images/events/flyer/2019/6/us-0615-1248533-list.jpg"/></a>
# <p class="counter nohide">
# <span>244</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1248533">
# <h1>
# Carl Cox presents Pure NY - Sold Out
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 16 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1220085"><img class="nohide" src="/images/events/flyer/2019/6/us-0616-1220085-list.jpg"/></a>
# <p class="counter nohide">
# <span>262</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1220085">
# <h1>
# Dirtybird BBQ - Brooklyn (Claude Vonstroke, Justin Martin, Gene Farris &amp; More)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 22 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1240196"><img class="nohide" src="/images/events/flyer/2019/6/us-0622-1240196-list.jpg"/></a>
# <p class="counter nohide">
# <span>835</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1240196">
# <h1>
# Mayan Warrior (Full Art Car) at The Brooklyn Mirage
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Wed, 3 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1259989"><img class="nohide" src="/images/events/flyer/2019/7/us-0703-1259989-list.jpg"/></a>
# <p class="counter nohide">
# <span>329</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1259989">
# <h1>
# Bedouin presents Saga
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 6 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256824"><img class="nohide" src="/images/events/flyer/2019/7/us-0706-1256824-list.jpg"/></a>
# <p class="counter nohide">
# <span>848</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1256824">
# <h1>
# Cityfox Arise: Maceo Plex, Anna, Nastia, Dusky &amp; More
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sun, 7 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1268685"><img class="nohide" src="/images/events/flyer/2019/7/us-0707-1268685-list.jpg"/></a>
# <p class="counter nohide">
# <span>238</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1268685">
# <h1>
# Mister Sunday: Theo Parrish All Day
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105873">Nowadays</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2019-06-04">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2019-06-18">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="2"/>
# <span>US</span><input id="country-name" type="hidden" value="United States of America"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li data-id="3"><a href="/events">United Kingdom</a></li><li class="selected" data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><
ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=105938">Brooklyn Mirage</a> /</li><li><a ga-event-action="Good Room" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=97606">Good Room</a> /</li><li><a ga-event-action="Bossa Nova Civic Club" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=71292">Bossa Nova Civic Club</a> /</li><li><a ga-event-action="MoMA PS1" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=2495">MoMA PS1</a> /</li><li><a ga-event-action="TBA Brooklyn" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=75374">TBA Brooklyn</a> /</li><li><a ga-event-action="House Of Yes" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=21488">House Of Yes</a> /</li><li><a ga-event-action="Le Bain" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=36873">Le Bain</a> /</li><li><a ga-event-action="Elsewhere" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=139960">Elsewhere</a> /</li><li><a ga-event-action="Nowadays" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=105873">Nowadays</a> /</li><li><a ga-event-action="Schimanski" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=126308">Schimanski</a> /</li><li><a ga-event-action="Avant Gardner" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=141127">Avant Gardner</a> /</li><li><a ga-event-action="Le Poisson Rouge" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=11796">Le Poisson Rouge</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=8">More New York clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/czechrepublic">Czech Republic</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/croatia">Croatia</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Madrid" ga-event-category="top-regions" ga-on="click" href="/guide/es/madrid">Madrid, ES</a> /</li><li><a ga-event-action="Montreal" ga-event-category="top-regions" ga-on="click" href="/guide/ca/montreal">Montreal, CA</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Lisbon" ga-event-category="top-regions" ga-on="click" href="/guide/pt/lisbon">Lisbon, PT</a> /</li><li><a ga-event-action="Chicago" ga-event-category="top-regions" ga-on="click" href="/guide/us/chicago">Chicago, US</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2019-06-04">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2019-06-18">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 06 Jun 2019</p>
# <a href="/news/43909">
# <img class="thumb" src="/images/news/2019/beat-hotel-glastonbury-festival-lineup-2019.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43909/?comments=1">Post a comment</a>
# </p><a href="/news/43909">
# <h1>Beat Hotel to leave Glastonbury after 2019 festival</h1>
# </a>
# <p class="copy">Bicep, Avalon Emerson, Midland, Peach, Seth Troxler and more will play the venue's last stand at Worthy Farm.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sun, 09 Jun 2019</p>
# <a href="/news/43915">
# <img class="thumb" src="/images/news/2019/moodymann-new-album-sinner-digital-release.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43915/?comments=1">Post a comment</a>
# </p><a href="/news/43915">
# <h1>Moodymann unveils expanded digital release of new album, Sinner</h1>
# </a>
# <p class="copy">The Detroit artist uploaded Sinner to his Bandcamp today.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 04 Jun 2019</p>
# <a href="/news/43897">
# <img class="thumb" src="/images/news/2019/daphni-dan-snaith.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43897/?comments=1">Post a comment</a>
# </p><a href="/news/43897">
# <h1>Daphni slips out new white-label EP</h1>
# </a>
# <p class="copy">The 12-inch is Dan Snaith's first record since 2017.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu,
Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
events = soup.find('div', id='event-listing')
print(len(events))
# Out:
# 3

# %%
list_items = events.findAll('li')
len(list_items)
# Out:
# 140

# %%
list_items[1]
# Out:
# <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-11T00:00" itemprop="startDate">2019-06-11T00:00</time></span><a href="/events/1275001"><img height="76" src="/images/events/flyer/2019/6/us-0611-1275001-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1275001" itemprop="url" title="Event details of Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz">Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz</a> <span>at <a href="/club.aspx?id=138627">Ms. Yoo</a></span></h1><div class="grey event-lineup">Carlos Alkalina, playsuit, Sveta Voice, Pjay, Bytz</div><p class="attending"><span>5</span> Attending</p></div></article></li>

# %%
rows = []
for item in list_items:
    date = item.find('p', class_='eventDate date')
    event = item.find('h1', class_='event-title')
    if event:
        details = event.text.split(' at ')
        artists = details[0].strip()
        venue = details[1].strip()
        attending = item.find('p', class_='attending')
        if attending:
            no_attending = attending.text
        else:
            no_attending = 0
        rows.append([artists, venue, cur_date, no_attending])
    elif date:
        cur_date = date.text
    else:
        continue

# %%
rows
# Out:
# [['Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz',
#   'Ms. Yoo',
#   'Tue, 11 Jun 2019 /',
#   '5 Attending'],
#  ['Cancelled', '14B Rooftop / Lounge', 'Tue, 11 Jun 2019 /', '2 Attending'],
#  ['Tempo with Steve Tek (Open to Close)',
#   'TBA Brooklyn',
#   'Tue, 11 Jun 2019 /',
#   '2 Attending'],
#  ['Feel Real with DJ Disciple, Ejoe Wilson Friends',
#   'Rumpus Room',
#   'Tue, 11 Jun 2019 /',
#   '1 Attending'],
#  ['Small Rave 019 - Xcreenplay (Live)/ Perris/ Fergus Waveforms',
#   'Bossa Nova Civic Club',
#   'Tue, 11 Jun 2019 /',
#   0],
#  ['Feel Free: Grand Atrium + Buskko', 'Kinfolk 90', 'Tue, 11 Jun 2019 /', 0],
#  ["Nacho Rojas' B2b2b2b2b2b2b Bday Bash [actual Bday & day of Arrival in US]",
#   'TBA - New York',
#   'Wed, 12 Jun 2019 /',
#   '5 Attending'],
#  ['Full Flex with DJ Swagger, Klein Zage b2b Joey G ii',
#   'Good Room',
#   'Wed, 12 Jun 2019 /',
#   '8 Attending'],
#  ['Party Party Party',
#   'Bossa Nova Civic Club',
#   'Wed, 12 Jun 2019 /',
#   '8 Attending'],
#  ['Ūndisclosed - Ryan Crosson, Jeff Veliz, Martin, Juan Jimenez',
#   'TBA Brooklyn',
#   'Wed, 12 Jun 2019 /',
#   '7 Attending'],
#  ['One Night Only', 'Dekalb Stage', 'Wed, 12 Jun 2019 /', 0],
#  ['Expansions NYC Special Guests Josh Milan, Ian Friday, and Jihad Muhammad',
#   'Doux Supper Club',
#   'Wed, 12 Jun 2019 /',
#   0],
#  ['Laylit Days with Wake Island and Saphe',
#   'Elsewhere',
#   'Wed, 12 Jun 2019 /',
#   0],
#  ['Open Decks Session 67', 'Eris', 'Wed, 12 Jun 2019 /', 0],
#  ['2nd Wednesdays', "Quinn's", 'Wed, 12 Jun 2019 /', 0],
#  ['Will Shore Residency', 'Jupiter Disco', 'Wed, 12 Jun 2019 /', 0],
#  ['Morgana [free entry]: Atish, John Tejada Live, Nicone, Patricio',
#   'Brooklyn Mirage',
#   'Thu, 13 Jun 2019 /',
#   '571 Attending'],
#  ['Susanne Bartsch presents: Club Heartbreak with Mark Ronson and Special Guests',
#   'Elsewhere',
#   'Thu, 13 Jun 2019 /',
#   '33 Attending'],
#  ['Ascend: The Scumfrog, Special Guest, Gio Israel by The Sonic Jungle',
#   'The Williamsburg Hotel',
#   'Thu, 13 Jun 2019 /',
#   '11 Attending'],
#  ['Body Music Therapy presents LDY OSC',
#   'Nowadays',
#   'Thu, 13 Jun 2019 /',
#   '6 Attending'],
#  ['Omnom / Vnssa - Biome002',
#   'Good Room',
#   'Thu, 13 Jun 2019 /',
#   '7 Attending'],
#  ['Hello Sailor Record Release Party',
#   'public records',
#   'Thu, 13 Jun 2019 /',
#   '2 Attending'],
#  ['Brooklyn Record Exchange Residency with DJ Krasdale and Ben Steidel',
#   'Elsewhere',
#   'Thu, 13 Jun 2019 /',
#   0],
#  ['Air A Danser: w/ Sacha Mambo', 'Cape House', 'Thu, 13 Jun 2019 /', 0],
#  ['Tropical Past & Future', 'Black Flamingo', 'Thu, 13 Jun 2019 /', 0],
#  ['Groundwire', 'H0L0', 'Thu, 13 Jun 2019 /', 0],
#  ['Shak Shaka', 'Starr Bar', 'Thu, 13 Jun 2019 /', 0],
#  ['Anything Goes: Stelios Vassiloudis, Dysco & Krsn',
#   '1 Oak',
#   'Thu, 13 Jun 2019 /',
#   0],
#  ['The WARPER PARTY', 'The Deep End', 'Thu, 13 Jun 2019 /', 0],
#  ['Like That Recs', 'Bossa Nova Civic', 'Thu, 13 Jun 2019 /', 0],
#  ['CCC Presents: World is Ending ft JPatt, Passè, Kyle.Wav, Lefti, LV RSL',
#   'Rose Gold',
#   'Thu, 13 Jun 2019 /',
#   0],
#  ['Claptone The Masquerade',
#   'Brooklyn Mirage',
#   'Fri, 14 Jun 2019 /',
#   '199 Attending'],
#  ['Fiedel / Tin Man / Justin Cudmore',
#   'BASEMENT',
#   'Fri, 14 Jun 2019 /',
#   '72 Attending'],
#  ['Bubble_t Chandelier_by_night with Joey Labeija, Howin Wong and More',
#   'Elsewhere',
#   'Fri, 14 Jun 2019 /',
#   '64 Attending'],
#  ['Wonderwheel Recordings & Junxion present: Quantic (DJ) and More Rooftop',
#   'Elsewhere',
#   'Fri, 14 Jun 2019 /',
#   '22 Attending'],
#  ['Lessons with Shakolin & Rasho',
#   'TBA - Brooklyn',
#   'Fri, 14 Jun 2019 /',
#   '22 Attending'],
#  ['Inoki Party: Oliver Smith & Myon (Anjunabeats)',
#   'Analog Bkny',
#   'Fri, 14 Jun 2019 /',
#   '21 Attending'],
#  ["Yoshitoshi's 25th Anniversary Boat Party NYC with Sharam & Sacha Robotti",
#   'Pier 15',
#   'Fri, 14 Jun 2019 /',
#   '16 Attending'],
#  ['Discotechnique: Rainbow Disco',
#   'House Of Yes',
#   'Fri, 14 Jun 2019 /',
#   '14 Attending'],
#  ['Eli Escobar, Pleasure Jams, ¡Capicua EP! Release Party with Toribio, Jitwam & Ensemble Entendu',
#   'Good Room',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Friday: Riobamba, DJ Haram and Elosi', 'Nowadays', 'Fri, 14 Jun 2019 /', 0],
#  ['Air ≋ 01: Lee Curtiss/ Renegade Masters/ Funky People/ Delivery',
#   'Bogart House',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Body Music Therapy presents LDY OSC', 'Nowadays', 'Fri, 14 Jun 2019 /', 0],
#  ['Microwave with Danny Langan, Junior, Nico Laa, Oktave & Gian-Paul',
#   'TBA Brooklyn',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Muévete Jevi 7.0 with Gooddroid, Lita, Fried Plátano and Gran Reserva',
#   'Elsewhere',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ["Quo Vadis presents Muqata'a, King Vision Ultra and Bonnie Baxter",
#   'public records',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Kiss & Tell: Speed Dating', 'Mad Tropical', 'Fri, 14 Jun 2019 /', 0],
#  ['Afterhours - Bushwick A/V: Laydee V / Nacho Rojas',
#   'Polygon BK',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['NYC Blackout Yacht Party Cruise Cabana Yacht 2019',
#   'Skyport Marina',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['NYC Hip Hop vs. Reggae Yacht Party Cruise Cabana Yacht 2019',
#   'Skyport Marina',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ["D'Noir AM feat. Moya, Reymerh", 'Polygon BK', 'Fri, 14 Jun 2019 /', 0],
#  ["Carl Cox & Eric Powell's Mobile Disco",
#   'Kings Hall - Avant Gardner',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Ge-Ology', 'public records', 'Fri, 14 Jun 2019 /', 0],
#  ['Kitsuné x New Museum present the Sunset Series',
#   'New Museum',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Samo Nights: Sacha Mambo (Madacam Mambo/ NY Debut / FR) & Facets',
#   'TBA - Brooklyn',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Esscalation Music Festival', 'Melrose Ballroom', 'Fri, 14 Jun 2019 /', 0],
#  ['The New Deal (Late Night)', 'Brooklyn Bowl', 'Fri, 14 Jun 2019 /', 0],
#  ['2kDeep NYC presents: 360 DNB Showcase feat. Nickyblackmarket DJ Profile & Fatman D',
#   'H0L0',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Amici Tomodachi presents: Midnight Matsuri with Francis Nishida and DJ Monchan',
#   'Trans Pecos',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Rich Medina all Night', 'Le Bain', 'Fri, 14 Jun 2019 /', 0],
#  ['Select Summer Fridays', 'Le Bain', 'Fri, 14 Jun 2019 /', 0],
#  ['Chaotic Good: Antenes, Dan Snazelle Live, Rob Seurat, Din',
#   'Bossa Nova Civic Club',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['House Music Happy Hour with DJ Mkhuseli',
#   'Bean & Barley Harlem',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Blame It On The Midnight Yacht Cruise',
#   'Harbor Lights Yacht',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Good Looks and Schimanski present: Svdden Death, 13, Snowmass',
#   'Schimanski',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Yalla!', "C'mon Everybody", 'Fri, 14 Jun 2019 /', 0],
#  ['Material 18: Residents Edition', 'Jupiter Disco', 'Fri, 14 Jun 2019 /', 0],
#  ['NYC Blackout Yacht Party Cruise',
#   'Skyport Marina',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['The Zapp Band, Futuretype EP Release, Leo Nocentelli',
#   'Brooklyn Bowl',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['Dobao (Argentina) x Paul Raffaele x David Marston',
#   'Black Flamingo',
#   'Fri, 14 Jun 2019 /',
#   0],
#  ['La Luna - The Black Madonna, DJ Harvey, DJ Tennis, Moodymann',
#   'Knockdown Center',
#   'Sat, 15 Jun 2019 /',
#   '342 Attending'],
#  ['Carl Cox presents Pure NY - Sold Out',
#   'Brooklyn Mirage',
#   'Sat, 15 Jun 2019 /',
#   '244 Attending'],
#  ['Chus & Ceballos Boat Party - Stereo On The Hudson (Pirate Edition)',
#   'Circle Line Cruises',
#   'Sat, 15 Jun 2019 /',
#   '119 Attending'],
#  ['Fleetmac Wood presents Gold Dust Disco - Brooklyn',
#   'Industry City',
#   'Sat, 15 Jun 2019 /',
#   '97 Attending'],
#  ['Magda, Mike Servito, Love Letters, Patrick Russell, LDY OSC',
#   'Good Room',
#   'Sat, 15 Jun 2019 /',
#   '60 Attending'],
#  ['Saturday: Anthony Parasole All Night',
#   'Nowadays',
#   'Sat, 15 Jun 2019 /',
#   '58 Attending'],
#  ['The Magician, Aston Shuffle, Zephyr Ann, The Golden Pony and More',
#   'Elsewhere',
#   'Sat, 15 Jun 2019 /',
#   '52 Attending'],
#  ['Have you Ever had a Dream',
#   'The Williamsburg Hotel',
#   'Sat, 15 Jun 2019 /',
#   '51 Attending'],
#  ['Jellybean Rocks The House ~ The Boat Ride with Jellybean Benitez',
#   'Circle Line Cruises',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Zimmer (DJ Set',
#   'Elsewhere Rooftop), Cry Baby, Evan Michael and Jonny Sum',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['EDX - NO Xcuses NYC 2019 - Brunch Yacht Club on Infinity',
#   'Hornblower Cruise',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Goonroom presents: Breakwave [Meine Nacht - US Debut], DJ Voices',
#   'Rose Gold',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Groovy Groovy — Stabudown Productions & Lawd Knows',
#   'H0L0',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Frequencies - Sleepy & Boo, Past Deep, Delalvv, Happy Hour',
#   'TBA Brooklyn',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Mathias Kaden B2B Hector Cuoto', 'Analog Bkny', 'Sat, 15 Jun 2019 /', 0],
#  ['Sander Kleinenberg', 'House Of Yes', 'Sat, 15 Jun 2019 /', 0],
#  ['Panda Bear', '99 Scott Ave', 'Sat, 15 Jun 2019 /', 0],
#  ['Joint Venture: Rissa Garcia, Forward Disco, Ruez and More',
#   'Bogart House',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ["Quo Vadis presents Muqata'a, King Vision Ultra and Bonnie Baxter",
#   'public records',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['PA-RT Liberty', 'Boat - Liberty Belle', 'Sat, 15 Jun 2019 /', 0],
#  ['Philippines Independence Day Boat Party with Shawn Wasabi',
#   'Pier 40',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ["D'Noir AM feat. Cristian Arango (Extended Set)",
#   'Polygon BK',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Afterhours - Bushwick A/V: Christian Arango / Cape / Mario Polanco',
#   'Polygon BK',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Distinct Motive & Levitation Jones Deluge',
#   'The Brown Note',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Rick Wilhite & Nathaniel Jay', 'public records', 'Sat, 15 Jun 2019 /', 0],
#  ["Laraaji Performs 'Day of Radiance'",
#   'public records',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Mike Guimond all Night', 'Le Bain', 'Sat, 15 Jun 2019 /', 0],
#  ['☆ my Chemical Trollmance ☆', 'Mood Ring', 'Sat, 15 Jun 2019 /', 0],
#  ['Shlohmo', 'Elsewhere', 'Sat, 15 Jun 2019 /', 0],
#  ['Ubiquity Soul Summer House Music Series',
#   'Military Park',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['PFR Live: Longer, Luvworks, Secondary Five, Hank The Mason, Hidden Prism (DJ Set)',
#   'TBA - Brooklyn',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['13th Hour presents! Ricky Razu', 'Jupiter Disco', 'Sat, 15 Jun 2019 /', 0],
#  ['Esscalation Music Festival', 'Melrose Ballroom', 'Sat, 15 Jun 2019 /', 0],
#  ['Caché Life presents a Night with Brooklyn Hustle',
#   'Club Room - Soho Grand Hotel',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Flanger ⥸ with 2Lanes, Oscar Huang, Dj Worldview, Opheliaxz',
#   '444 Club',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Assembly: Suzi Analogue, Pamela Z', 'The Kitchen', 'Sat, 15 Jun 2019 /', 0],
#  ['Jennifer Walshe & Wobbly', 'Issue Project Room', 'Sat, 15 Jun 2019 /', 0],
#  ['Select Summer Fridays', 'Le Bain', 'Sat, 15 Jun 2019 /', 0],
#  ['Xmpz / Fana / Haruka / dj Celes',
#   'Bossa Nova Civic Club',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Soulful Sessions', 'Halcyon The Shop', 'Sat, 15 Jun 2019 /', 0],
#  ['United Spirits-Butch SOS Birthday Beast621',
#   "Frank's Lounge",
#   'Sat, 15 Jun 2019 /',
#   0],
#  ["Nacho Rojas's Bday Boat Party",
#   'Hornblower Cruise',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Feel Free NYC presents Refresh Rate - Panooc (Xoxa) / Grand Atrium / Buskko',
#   'Wonderville',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Move for Wolves with MANIK + Son of Sound',
#   'The Well',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Soul Summit Music', 'Black Flamingo', 'Sat, 15 Jun 2019 /', 0],
#  ['Rufus Gibson presents: Titonton Duvante',
#   'Gypsy Parlor, Buffalo/Rochester',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Justus Worldwide presents: Coney Island Boardwalk Parties',
#   'Justus Worldwide Coney Island Boardwalk',
#   'Sat, 15 Jun 2019 /',
#   0],
#  ['Dirtybird BBQ - Brooklyn (Claude Vonstroke, Justin Martin, Gene Farris & More)',
#   'Brooklyn Mirage',
#   'Sun, 16 Jun 2019 /',
#   '262 Attending'],
#  ['Mister Sunday', 'Nowadays', 'Sun, 16 Jun 2019 /', '40 Attending'],
#  ['Vinyl BBQ', '99 Scott Ave', 'Sun, 16 Jun 2019 /', '11 Attending'],
#  ['PA-RT Liberty',
#   'Boat - Liberty Belle',
#   'Sun, 16 Jun 2019 /',
#   '2 Attending'],
#  ['Landed. Vol. 03', 'Jupiter Disco', 'Sun, 16 Jun 2019 /', 0],
#  ['Sunset Sunday: Turntables on the Hudson',
#   'Le Bain',
#   'Sun, 16 Jun 2019 /',
#   0],
#  ['Artyparty 1', 'H0L0', 'Sun, 16 Jun 2019 /', 0],
#  ['Assembly: King Britt, Richard Kennedy',
#   'The Kitchen',
#   'Sun, 16 Jun 2019 /',
#   0],
#  ['Dirtybird BBQ - Brooklyn (Claude Vonstroke, Justin Martin, Gene Farris & More)',
#   'Brooklyn Mirage',
#   'Mon, 17 Jun 2019 /',
#   '262 Attending'],
#  ['Sunset Sunday: Turntables on the Hudson',
#   'Le Bain',
#   'Mon, 17 Jun 2019 /',
#   '2 Attending']]

# %%
date = list_items[0].find('p', class_='eventDate date')
print(date.text)
# Out:
# Tue, 11 Jun 2019 /

# %%
event = list_items[1].find('h1', class_='event-title')
print(event.text)
# Out:
# Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz at Ms. Yoo

# %%
details = event.text.split(' at ')

# %%
details
# Out:
# ['Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz', 'Ms. Yoo']

# %%
def scrape_events(events_page_url):
    #Your code here
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    events = soup.find('div', id='event-listing')
    list_items = events.findAll('li')
    
    rows = []
    for item in list_items:
        date = item.find('p', class_='eventDate date')
        event = item.find('h1', class_='event-title')
        if event:
            details = event.text.split(' at ')
            artists = details[0].strip()
            venue = details[1].strip()
            attending = item.find('p', class_='attending')
            try:
                no_attending = attending.text
            except:
                no_attending = np.nan
            rows.append([artists, venue, cur_date, no_attending])
        elif date:
            cur_date = date.text
        else:
            continue 
    
    
    df = pd.DataFrame(rows)
    df.columns = ["Event_Name", "Venue", "Event_Date", 
                  "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                             Event_Name  \
# 0      Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz
# 1                                            Cancelled
# 2                 Tempo with Steve Tek (Open to Close)
# 3      Feel Real with DJ Disciple, Ejoe Wilson Friends
# 4    Small Rave 019 - Xcreenplay (Live)/ Perris/ Fe...
# 5                     Feel Free: Grand Atrium + Buskko
# 6    Nacho Rojas' B2b2b2b2b2b2b Bday Bash [actual B...
# 7    Full Flex with DJ Swagger, Klein Zage b2b Joey...
# 8                                    Party Party Party
# 9    Ūndisclosed - Ryan Crosson, Jeff Veliz, Martin...
# 10                                      One Night Only
# 11   Expansions NYC Special Guests Josh Milan, Ian ...
# 12              Laylit Days with Wake Island and Saphe
# 13                               Open Decks Session 67
# 14                                Will Shore Residency
# 15                                      2nd Wednesdays
# 16   Morgana [free entry]: Atish, John Tejada Live,...
# 17   Susanne Bartsch presents: Club Heartbreak with...
# 18   Ascend: The Scumfrog, Special Guest, Gio Israe...
# 19                 Body Music Therapy presents LDY OSC
# 20                            Omnom / Vnssa - Biome002
# 21                   Hello Sailor Record Release Party
# 22   Brooklyn Record Exchange Residency with DJ Kra...
# 23                        Air A Danser: w/ Sacha Mambo
# 24                              Tropical Past & Future
# 25                                          Groundwire
# 26                                          Shak Shaka
# 27    Anything Goes: Stelios Vassiloudis, Dysco & Krsn
# 28                                    The WARPER PARTY
# 29                                      Like That Recs
# ..                                                 ...
# 97                          ☆ my Chemical Trollmance ☆
# 98                                             Shlohmo
# 99             Ubiquity Soul Summer House Music Series
# 100  PFR Live: Longer, Luvworks, Secondary Five, Ha...
# 101                     13th Hour presents! Ricky Razu
# 102                         Esscalation Music Festival
# 103   Caché Life presents a Night with Brooklyn Hustle
# 104  Flanger ⥸ with 2Lanes, Oscar Huang, Dj Worldvi...
# 105                  Assembly: Suzi Analogue, Pamela Z
# 106                           Jennifer Walshe & Wobbly
# 107                              Select Summer Fridays
# 108                    Xmpz / Fana / Haruka / dj Celes
# 109                                   Soulful Sessions
# 110         United Spirits-Butch SOS Birthday Beast621
# 111                      Nacho Rojas's Bday Boat Party
# 112  Feel Free NYC presents Refresh Rate - Panooc (...
# 113          Move for Wolves with MANIK + Son of Sound
# 114                                  Soul Summit Music
# 115            Rufus Gibson presents: Titonton Duvante
# 116  Justus Worldwide presents: Coney Island Boardw...
# 117  Dirtybird BBQ - Brooklyn (Claude Vonstroke, Ju...
# 118                                      Mister Sunday
# 119                                          Vinyl BBQ
# 120                                      PA-RT Liberty
# 114                           Black Flamingo  Sat, 15 Jun 2019 /
# 115          Gypsy Parlor, Buffalo/Rochester  Sat, 15 Jun 2019 /
# 116  Justus Worldwide Coney Island Boardwalk  Sat, 15 Jun 2019 /
# 117                          Brooklyn Mirage  Sun, 16 Jun 2019 /
# 118                                 Nowadays  Sun, 16 Jun 2019 /
# 119                             99 Scott Ave  Sun, 16 Jun 2019 /
# 120                     Boat - Liberty Belle  Sun, 16 Jun 2019 /
# 121                            Jupiter Disco  Sun, 16 Jun 2019 /
# 122                                  Le Bain  Sun, 16 Jun 2019 /
# 123                                     H0L0  Sun, 16 Jun 2019 /
# 124                              The Kitchen  Sun, 16 Jun 2019 /
# 125                          Brooklyn Mirage  Mon, 17 Jun 2019 /
# 126                                  Le Bain  Mon, 17 Jun 2019 /
#
#     Number_of_Attendees
# 0           5 Attending
# 1           2 Attending
# 2           2 Attending
# 3           1 Attending
# 4                   NaN
# 5                   NaN
# 6           5 Attending
# 7           8 Attending
# 8           8 Attending
# 9           7 Attending
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16        579 Attending
# 17         33 Attending
# 18         11 Attending
# 19          6 Attending
# 20          7 Attending
# 21          2 Attending
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# ..                  ...
# 97                  NaN
# 98                  NaN
# 99                  NaN
# 100                 NaN
# 101                 NaN
# 102                 NaN
# 103                 NaN
# 104                 NaN
# 105                 NaN
# 106                 NaN
# 107                 NaN
# 108                 NaN
# 109                 NaN
# 110                 NaN
# 111                 NaN
# 112                 NaN
# 113                 NaN
# 114                 NaN
# 115                 NaN
# 116                 NaN
# 117       263 Attending
# 118        40 Attending
# 119        11 Attending
# 120         2 Attending
# 121                 NaN
# 122                 NaN
# 123                 NaN
# 124                 NaN
# 125       263 Attending
# 126         2 Attending
#
# [127 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    next_page = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = 'https://www.residentadvisor.net' + next_page
    return next_page_url

# %%
next_page('https://www.residentadvisor.net/events')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2019-06-18'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
url = 'https://www.residentadvisor.net/events'
df = scrape_events(url)

while len(df) < 500: 
    url = next_page(url)
    df2 = scrape_events(url)
    df = pd.concat([df, df2])

print(len(df))
# Out:
# 513

# %%
df.head()
# Out:
#                                           Event_Name                  Venue  \
# 0    Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz                Ms. Yoo
# 1                                          Cancelled   14B Rooftop / Lounge
# 2               Tempo with Steve Tek (Open to Close)           TBA Brooklyn
# 3    Feel Real with DJ Disciple, Ejoe Wilson Friends            Rumpus Room
# 4  Small Rave 019 - Xcreenplay (Live)/ Perris/ Fe...  Bossa Nova Civic Club
#
#            Event_Date Number_of_Attendees
# 0  Tue, 11 Jun 2019 /         5 Attending
# 1  Tue, 11 Jun 2019 /         2 Attending
# 2  Tue, 11 Jun 2019 /         2 Attending
# 3  Tue, 11 Jun 2019 /         1 Attending
# 4  Tue, 11 Jun 2019 /                 NaN

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
